# %%
import os
import glob
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models, Input, mixed_precision
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import (
    ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
)

# ─────────────────────────────────────────────
#  MIXED PRECISION  (VRAM অর্ধেক হয়ে যায়)
# ─────────────────────────────────────────────
mixed_precision.set_global_policy('mixed_float16')
os.environ['TF_GPU_ALLOCATOR'] = 'cuda_malloc_async'

# GPU memory growth — শুরুতেই সব মেমরি নেবে না
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    print(f"GPU found: {[g.name for g in gpus]}")

# ─────────────────────────────────────────────
#  CONFIG  — VRAM অনুযায়ী টিউন করুন
# ─────────────────────────────────────────────
IMG_SIZE   = 256
BATCH_SIZE = 4        # OOM হলে 2 করুন
EPOCHS     = 100
DATA_PATH  = '/mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/DataSets/Kvasir-SEG'
MODEL_SAVE = '/mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras'

# ─────────────────────────────────────────────
#  AUGMENTATION
# ─────────────────────────────────────────────
def augment(img, mask):
    if tf.random.uniform(()) > 0.5:
        img  = tf.image.flip_left_right(img)
        mask = tf.image.flip_left_right(mask)
    if tf.random.uniform(()) > 0.5:
        img  = tf.image.flip_up_down(img)
        mask = tf.image.flip_up_down(mask)
    img = tf.image.random_brightness(img, 0.15)
    img = tf.image.random_contrast(img, 0.85, 1.15)
    img = tf.clip_by_value(img, 0.0, 1.0)
    return img, mask

# ─────────────────────────────────────────────
#  PREPROCESSING
# ─────────────────────────────────────────────
def process_path(img_path, mask_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32) / 255.0

    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_image(mask, channels=1, expand_animations=False)
    mask = tf.image.resize(mask, [IMG_SIZE, IMG_SIZE],
                           method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    mask = tf.cast(mask, tf.float32) / 255.0
    mask = tf.where(mask > 0.5, 1.0, 0.0)
    return img, mask

def get_dataset(x, y, batch=BATCH_SIZE, augment_data=False):
    ds = tf.data.Dataset.from_tensor_slices((x, y))
    ds = ds.shuffle(buffer_size=len(x), reshuffle_each_iteration=True)
    ds = ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)
    if augment_data:
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(batch)
    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds

# ─────────────────────────────────────────────
#  LOSS & METRICS
# ─────────────────────────────────────────────
def dice_coef(y_true, y_pred, smooth=1.0):
    y_true = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2.0 * intersection + smooth) / (
        tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth
    )

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def bce_dice_loss(y_true, y_pred):
    y_true_f = tf.cast(y_true, tf.float32)
    y_pred_f = tf.cast(y_pred, tf.float32)
    bce = tf.reduce_mean(
        tf.keras.losses.binary_crossentropy(y_true_f, y_pred_f)
    )
    return bce + dice_loss(y_true_f, y_pred_f)

def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    return (intersection + 1.0) / (union + 1.0)

# ─────────────────────────────────────────────
#  LIGHTWEIGHT U-NET  — 4GB VRAM এ চলবে
#  আগের 1024-filter bottleneck বাদ দেওয়া হয়েছে
# ─────────────────────────────────────────────
def conv_block(x, filters, dropout_rate=0.0):
    """Conv → BN → ReLU × 2  (mixed_float16 compatible)"""
    x = layers.Conv2D(filters, 3, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    if dropout_rate > 0:
        x = layers.SpatialDropout2D(dropout_rate)(x)
    x = layers.Conv2D(filters, 3, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

def build_unet_lite(input_shape=(IMG_SIZE, IMG_SIZE, 3)):
    """
    Filter map:  64 → 128 → 256 → 512 (bottleneck)
    আগের 1024-filter layer বাদ — VRAM ~60% কমে যায়
    """
    inputs = Input(input_shape)

    # ── Encoder ──────────────────────────
    c1 = conv_block(inputs, 32)                      # 256×256×32
    p1 = layers.MaxPooling2D(2)(c1)                  # 128×128

    c2 = conv_block(p1, 64)                          # 128×128×64
    p2 = layers.MaxPooling2D(2)(c2)                  # 64×64

    c3 = conv_block(p2, 128, dropout_rate=0.1)       # 64×64×128
    p3 = layers.MaxPooling2D(2)(c3)                  # 32×32

    c4 = conv_block(p3, 256, dropout_rate=0.2)       # 32×32×256
    p4 = layers.MaxPooling2D(2)(c4)                  # 16×16

    # ── Bottleneck ───────────────────────
    b = conv_block(p4, 512, dropout_rate=0.3)        # 16×16×512  ← আগে 1024 ছিল

    # ── Decoder ──────────────────────────
    u4 = layers.Conv2DTranspose(256, 2, strides=2, padding='same')(b)
    u4 = layers.concatenate([u4, c4])
    c5 = conv_block(u4, 256, dropout_rate=0.2)

    u3 = layers.Conv2DTranspose(128, 2, strides=2, padding='same')(c5)
    u3 = layers.concatenate([u3, c3])
    c6 = conv_block(u3, 128, dropout_rate=0.1)

    u2 = layers.Conv2DTranspose(64, 2, strides=2, padding='same')(c6)
    u2 = layers.concatenate([u2, c2])
    c7 = conv_block(u2, 64)

    u1 = layers.Conv2DTranspose(32, 2, strides=2, padding='same')(c7)
    u1 = layers.concatenate([u1, c1])
    c8 = conv_block(u1, 32)

    # float32 output — mixed_precision এ sigmoid সবসময় float32 হওয়া উচিত
    outputs = layers.Conv2D(1, 1, activation='sigmoid', dtype='float32')(c8)

    return models.Model(inputs, outputs, name='U-Net-Lite')

# ─────────────────────────────────────────────
#  TEST & DISPLAY
# ─────────────────────────────────────────────
def test_and_display(model, image_path):
    img     = cv2.imread(image_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_res = cv2.resize(img_rgb, (IMG_SIZE, IMG_SIZE))
    inp     = np.expand_dims(img_res / 255.0, axis=0).astype(np.float32)

    pred_mask = model.predict(inp, verbose=0)[0]
    mask_bin  = (pred_mask > 0.5).astype(np.uint8)
    mask_3d   = np.concatenate([mask_bin] * 3, axis=-1)
    extracted = (img_res * mask_3d).astype(np.uint8)

    titles = ['Original', 'Predicted Mask', 'Extracted Polyp']
    images = [img_res, pred_mask.squeeze(), extracted]
    plt.figure(figsize=(15, 5))
    for i in range(3):
        plt.subplot(1, 3, i + 1)
        plt.imshow(images[i], cmap='gray' if i == 1 else None)
        plt.title(titles[i], fontsize=14)
        plt.axis('off')
    plt.tight_layout()
    plt.savefig('prediction_result.png', dpi=150)
    plt.show()

# ─────────────────────────────────────────────
#  MAIN
# ─────────────────────────────────────────────
if __name__ == '__main__':

    images = sorted(glob.glob(os.path.join(DATA_PATH, 'images/*.jpg')))
    masks  = sorted(glob.glob(os.path.join(DATA_PATH, 'masks/*.jpg')))
    print(f"Total samples: {len(images)}")

    train_x, val_x, train_y, val_y = train_test_split(
        images, masks, test_size=0.2, random_state=42
    )
    print(f"Train: {len(train_x)}  |  Val: {len(val_x)}")

    train_ds = get_dataset(train_x, train_y, batch=BATCH_SIZE, augment_data=True)
    val_ds   = get_dataset(val_x,   val_y,   batch=BATCH_SIZE, augment_data=False)

    unet = build_unet_lite()
    unet.summary()

    # Mixed precision → optimizer loss scaling দরকার
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
    optimizer = mixed_precision.LossScaleOptimizer(optimizer)

    unet.compile(
        optimizer=optimizer,
        loss=bce_dice_loss,
        metrics=[dice_coef, iou_metric, 'accuracy']
    )

    os.makedirs(os.path.dirname(MODEL_SAVE), exist_ok=True)

    callbacks = [
        ModelCheckpoint(MODEL_SAVE, monitor='val_dice_coef',
                        save_best_only=True, mode='max', verbose=1),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                          patience=7, min_lr=1e-7, verbose=1),
        EarlyStopping(monitor='val_dice_coef', patience=20,
                      restore_best_weights=True, mode='max', verbose=1),
    ]

    print("\n========== Training Started ==========")
    history = unet.fit(
        train_ds,
        validation_data=val_ds,
        epochs=EPOCHS,
        callbacks=callbacks
    )
    print("========== Training Complete ==========\n")

    # ── Plot ──────────────────────────────────
    fig, axes = plt.subplots(1, 3, figsize=(18, 5))
    axes[0].plot(history.history['loss'],          label='Train')
    axes[0].plot(history.history['val_loss'],      label='Val')
    axes[0].set_title('BCE + Dice Loss'); axes[0].legend()

    axes[1].plot(history.history['dice_coef'],     label='Train')
    axes[1].plot(history.history['val_dice_coef'], label='Val')
    axes[1].set_title('Dice Coefficient'); axes[1].legend()

    axes[2].plot(history.history['iou_metric'],     label='Train')
    axes[2].plot(history.history['val_iou_metric'], label='Val')
    axes[2].set_title('IoU Score'); axes[2].legend()

    plt.tight_layout()
    plt.savefig('training_history.png', dpi=150)
    plt.show()

    # if images:
    #     test_and_display(unet, images[0])
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778330443.811825   21121 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# GPU found: ['/physical_device:GPU:0']
# Total samples: 1000
# Train: 800  |  Val: 200
# I0000 00:00:1778330488.161563   21121 gpu_process_state.cc:208] Using CUDA malloc Async allocator for GPU: 0
# I0000 00:00:1778330488.163051   21121 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5563 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "U-Net-Lite"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │      9,216 │ activation[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     18,432 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │     36,864 │ activation_2[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │     73,728 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d   │ (None, 64, 64,    │          0 │ activation_4[0][… │
# │ (SpatialDropout2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    147,456 │ spatial_dropout2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │    294,912 │ max_pooling2d_2[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_1 │ (None, 32, 32,    │          0 │ activation_6[0][… │
# │ (SpatialDropout2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │    589,824 │ spatial_dropout2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │  1,179,648 │ max_pooling2d_3[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_2 │ (None, 16, 16,    │          0 │ activation_8[0][… │
# │ (SpatialDropout2D)  │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │  2,359,296 │ spatial_dropout2… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 32, 32,    │    524,544 │ activation_9[0][… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │  1,179,648 │ concatenate[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_3 │ (None, 32, 32,    │          0 │ activation_10[0]… │
# │ (SpatialDropout2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │    589,824 │ spatial_dropout2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 64, 64,    │    131,200 │ activation_11[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │    294,912 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_4 │ (None, 64, 64,    │          0 │ activation_12[0]… │
# │ (SpatialDropout2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │    147,456 │ spatial_dropout2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 128, 128,  │     32,832 │ activation_13[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │     73,728 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │     36,864 │ activation_14[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 256, 256,  │      8,224 │ activation_15[0]… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │     18,432 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │      9,216 │ activation_16[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │         33 │ activation_17[0]… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,768,929 (29.64 MB)
#  Trainable params: 7,763,041 (29.61 MB)
#  Non-trainable params: 5,888 (23.00 KB)
# ========== Training Started ==========
# Epoch 1/100
# I0000 00:00:1778330500.453431   21528 service.cc:153] XLA service 0x7622c405cc20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1778330500.453517   21528 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9 (Driver: 12.7.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.21.1)
# I0000 00:00:1778330500.675431   21528 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1778330502.841159   21528 cuda_dnn.cc:461] Loaded cuDNN version 92101
# I0000 00:00:1778330558.948036   21528 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7643 - dice_coef: 0.3083 - iou_metric: 0.2236 - loss: 1.1336
# Epoch 1: val_dice_coef improved from None to 0.29013, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 1: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 80s 55ms/step - accuracy: 0.7897 - dice_coef: 0.3161 - iou_metric: 0.2286 - loss: 1.0908 - val_accuracy: 0.2403 - val_dice_coef: 0.2901 - val_iou_metric: 0.1728 - val_loss: 6.6861 - learning_rate: 0.0010
# Epoch 2/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8065 - dice_coef: 0.3473 - iou_metric: 0.2576 - loss: 1.0341
# Epoch 2: val_dice_coef improved from 0.29013 to 0.29495, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 2: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.8084 - dice_coef: 0.3419 - iou_metric: 0.2499 - loss: 1.0404 - val_accuracy: 0.7952 - val_dice_coef: 0.2950 - val_iou_metric: 0.1904 - val_loss: 1.1365 - learning_rate: 0.0010
# Epoch 3/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8262 - dice_coef: 0.3642 - iou_metric: 0.2670 - loss: 1.0090
# Epoch 3: val_dice_coef improved from 0.29495 to 0.35101, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 3: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - accuracy: 0.8316 - dice_coef: 0.3842 - iou_metric: 0.2961 - loss: 0.9821 - val_accuracy: 0.4345 - val_dice_coef: 0.3510 - val_iou_metric: 0.2172 - val_loss: 5.1043 - learning_rate: 0.0010
# Epoch 4/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8338 - dice_coef: 0.4014 - iou_metric: 0.3167 - loss: 0.9588
# Epoch 4: val_dice_coef improved from 0.35101 to 0.39151, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 4: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - accuracy: 0.8372 - dice_coef: 0.4101 - iou_metric: 0.3224 - loss: 0.9470 - val_accuracy: 0.8627 - val_dice_coef: 0.3915 - val_iou_metric: 0.2766 - val_loss: 0.9918 - learning_rate: 0.0010
# Epoch 5/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8448 - dice_coef: 0.4379 - iou_metric: 0.3502 - loss: 0.9129
# Epoch 5: val_dice_coef did not improve from 0.39151
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.8485 - dice_coef: 0.4446 - iou_metric: 0.3544 - loss: 0.8994 - val_accuracy: 0.8587 - val_dice_coef: 0.3179 - val_iou_metric: 0.2096 - val_loss: 1.1164 - learning_rate: 0.0010
# Epoch 6/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8535 - dice_coef: 0.4490 - iou_metric: 0.3525 - loss: 0.8928
# Epoch 6: val_dice_coef improved from 0.39151 to 0.41931, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 6: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.8549 - dice_coef: 0.4572 - iou_metric: 0.3633 - loss: 0.8792 - val_accuracy: 0.8585 - val_dice_coef: 0.4193 - val_iou_metric: 0.3345 - val_loss: 0.9046 - learning_rate: 0.0010
# Epoch 7/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8616 - dice_coef: 0.4825 - iou_metric: 0.3884 - loss: 0.8438
# Epoch 7: val_dice_coef did not improve from 0.41931
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.8617 - dice_coef: 0.4806 - iou_metric: 0.3876 - loss: 0.8468 - val_accuracy: 0.5885 - val_dice_coef: 0.3774 - val_iou_metric: 0.2494 - val_loss: 1.5934 - learning_rate: 0.0010
# Epoch 8/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8650 - dice_coef: 0.4971 - iou_metric: 0.3981 - loss: 0.8281
# Epoch 8: val_dice_coef improved from 0.41931 to 0.47440, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 8: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - accuracy: 0.8632 - dice_coef: 0.4872 - iou_metric: 0.3914 - loss: 0.8391 - val_accuracy: 0.8575 - val_dice_coef: 0.4744 - val_iou_metric: 0.4024 - val_loss: 0.8444 - learning_rate: 0.0010
# Epoch 9/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8649 - dice_coef: 0.4896 - iou_metric: 0.3926 - loss: 0.8301
# Epoch 9: val_dice_coef improved from 0.47440 to 0.48706, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 9: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.8673 - dice_coef: 0.5015 - iou_metric: 0.4042 - loss: 0.8168 - val_accuracy: 0.8642 - val_dice_coef: 0.4871 - val_iou_metric: 0.3727 - val_loss: 0.8895 - learning_rate: 0.0010
# Epoch 10/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8716 - dice_coef: 0.5060 - iou_metric: 0.4111 - loss: 0.8090
# Epoch 10: val_dice_coef improved from 0.48706 to 0.54359, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 10: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.8699 - dice_coef: 0.5041 - iou_metric: 0.4080 - loss: 0.8133 - val_accuracy: 0.8434 - val_dice_coef: 0.5436 - val_iou_metric: 0.4112 - val_loss: 0.8746 - learning_rate: 0.0010
# Epoch 11/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8733 - dice_coef: 0.5046 - iou_metric: 0.4093 - loss: 0.8048
# Epoch 11: val_dice_coef did not improve from 0.54359
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.8719 - dice_coef: 0.5114 - iou_metric: 0.4154 - loss: 0.8026 - val_accuracy: 0.8514 - val_dice_coef: 0.5083 - val_iou_metric: 0.4376 - val_loss: 0.8245 - learning_rate: 0.0010
# Epoch 12/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8720 - dice_coef: 0.5237 - iou_metric: 0.4251 - loss: 0.7953
# Epoch 12: val_dice_coef did not improve from 0.54359
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - accuracy: 0.8757 - dice_coef: 0.5216 - iou_metric: 0.4244 - loss: 0.7849 - val_accuracy: 0.8401 - val_dice_coef: 0.5405 - val_iou_metric: 0.4224 - val_loss: 0.8477 - learning_rate: 0.0010
# Epoch 13/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8709 - dice_coef: 0.5252 - iou_metric: 0.4233 - loss: 0.7881
# Epoch 13: val_dice_coef did not improve from 0.54359
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.8765 - dice_coef: 0.5286 - iou_metric: 0.4286 - loss: 0.7727 - val_accuracy: 0.8815 - val_dice_coef: 0.5431 - val_iou_metric: 0.4575 - val_loss: 0.7457 - learning_rate: 0.0010
# Epoch 14/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8824 - dice_coef: 0.5369 - iou_metric: 0.4337 - loss: 0.7561
# Epoch 14: val_dice_coef did not improve from 0.54359
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.8801 - dice_coef: 0.5359 - iou_metric: 0.4341 - loss: 0.7656 - val_accuracy: 0.8880 - val_dice_coef: 0.4762 - val_iou_metric: 0.3798 - val_loss: 0.8341 - learning_rate: 0.0010
# Epoch 15/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8735 - dice_coef: 0.5310 - iou_metric: 0.4356 - loss: 0.7729
# Epoch 15: val_dice_coef improved from 0.54359 to 0.54698, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 15: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.8803 - dice_coef: 0.5425 - iou_metric: 0.4444 - loss: 0.7507 - val_accuracy: 0.8276 - val_dice_coef: 0.5470 - val_iou_metric: 0.4150 - val_loss: 0.8880 - learning_rate: 0.0010
# Epoch 16/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8831 - dice_coef: 0.5420 - iou_metric: 0.4442 - loss: 0.7521
# Epoch 16: val_dice_coef did not improve from 0.54698
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.8827 - dice_coef: 0.5412 - iou_metric: 0.4430 - loss: 0.7539 - val_accuracy: 0.8821 - val_dice_coef: 0.4728 - val_iou_metric: 0.3649 - val_loss: 0.8493 - learning_rate: 0.0010
# Epoch 17/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8808 - dice_coef: 0.5371 - iou_metric: 0.4365 - loss: 0.7642
# Epoch 17: val_dice_coef improved from 0.54698 to 0.57394, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 17: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - accuracy: 0.8820 - dice_coef: 0.5436 - iou_metric: 0.4441 - loss: 0.7518 - val_accuracy: 0.8846 - val_dice_coef: 0.5739 - val_iou_metric: 0.4672 - val_loss: 0.7319 - learning_rate: 0.0010
# Epoch 18/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8858 - dice_coef: 0.5611 - iou_metric: 0.4619 - loss: 0.7329
# Epoch 18: val_dice_coef improved from 0.57394 to 0.59321, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 18: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.8887 - dice_coef: 0.5598 - iou_metric: 0.4623 - loss: 0.7291 - val_accuracy: 0.8971 - val_dice_coef: 0.5932 - val_iou_metric: 0.4917 - val_loss: 0.6948 - learning_rate: 0.0010
# Epoch 19/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8854 - dice_coef: 0.5502 - iou_metric: 0.4540 - loss: 0.7458
# Epoch 19: val_dice_coef did not improve from 0.59321
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.8871 - dice_coef: 0.5588 - iou_metric: 0.4606 - loss: 0.7290 - val_accuracy: 0.8518 - val_dice_coef: 0.5687 - val_iou_metric: 0.4482 - val_loss: 0.8071 - learning_rate: 0.0010
# Epoch 20/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8894 - dice_coef: 0.5604 - iou_metric: 0.4589 - loss: 0.7237
# Epoch 20: val_dice_coef improved from 0.59321 to 0.59340, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 20: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.8900 - dice_coef: 0.5714 - iou_metric: 0.4717 - loss: 0.7069 - val_accuracy: 0.8714 - val_dice_coef: 0.5934 - val_iou_metric: 0.4889 - val_loss: 0.7288 - learning_rate: 0.0010
# Epoch 21/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8901 - dice_coef: 0.5687 - iou_metric: 0.4684 - loss: 0.7192
# Epoch 21: val_dice_coef did not improve from 0.59340
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - accuracy: 0.8902 - dice_coef: 0.5658 - iou_metric: 0.4661 - loss: 0.7200 - val_accuracy: 0.8645 - val_dice_coef: 0.5338 - val_iou_metric: 0.4493 - val_loss: 0.7857 - learning_rate: 0.0010
# Epoch 22/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9012 - dice_coef: 0.5917 - iou_metric: 0.4989 - loss: 0.6701
# Epoch 22: val_dice_coef improved from 0.59340 to 0.60931, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 22: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.9010 - dice_coef: 0.6023 - iou_metric: 0.5059 - loss: 0.6599 - val_accuracy: 0.8843 - val_dice_coef: 0.6093 - val_iou_metric: 0.5113 - val_loss: 0.7002 - learning_rate: 0.0010
# Epoch 23/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8967 - dice_coef: 0.5977 - iou_metric: 0.4925 - loss: 0.6826
# Epoch 23: val_dice_coef improved from 0.60931 to 0.63101, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 23: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.8992 - dice_coef: 0.5969 - iou_metric: 0.4953 - loss: 0.6720 - val_accuracy: 0.9011 - val_dice_coef: 0.6310 - val_iou_metric: 0.5209 - val_loss: 0.6373 - learning_rate: 0.0010
# Epoch 24/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9068 - dice_coef: 0.6055 - iou_metric: 0.5111 - loss: 0.6447
# Epoch 24: val_dice_coef did not improve from 0.63101
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9035 - dice_coef: 0.6130 - iou_metric: 0.5150 - loss: 0.6484 - val_accuracy: 0.9094 - val_dice_coef: 0.6022 - val_iou_metric: 0.4877 - val_loss: 0.6918 - learning_rate: 0.0010
# Epoch 25/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9027 - dice_coef: 0.6169 - iou_metric: 0.5196 - loss: 0.6451
# Epoch 25: val_dice_coef improved from 0.63101 to 0.63716, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 25: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - accuracy: 0.9021 - dice_coef: 0.6123 - iou_metric: 0.5129 - loss: 0.6526 - val_accuracy: 0.8812 - val_dice_coef: 0.6372 - val_iou_metric: 0.5106 - val_loss: 0.7060 - learning_rate: 0.0010
# Epoch 26/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9110 - dice_coef: 0.6273 - iou_metric: 0.5378 - loss: 0.6186
# Epoch 26: val_dice_coef did not improve from 0.63716
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9093 - dice_coef: 0.6298 - iou_metric: 0.5355 - loss: 0.6195 - val_accuracy: 0.8983 - val_dice_coef: 0.5256 - val_iou_metric: 0.3963 - val_loss: 0.7994 - learning_rate: 0.0010
# Epoch 27/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9129 - dice_coef: 0.6495 - iou_metric: 0.5505 - loss: 0.5930
# Epoch 27: val_dice_coef did not improve from 0.63716
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9134 - dice_coef: 0.6501 - iou_metric: 0.5544 - loss: 0.5899 - val_accuracy: 0.9088 - val_dice_coef: 0.6122 - val_iou_metric: 0.5029 - val_loss: 0.6694 - learning_rate: 0.0010
# Epoch 28/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9189 - dice_coef: 0.6599 - iou_metric: 0.5597 - loss: 0.5710
# Epoch 28: val_dice_coef improved from 0.63716 to 0.65823, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 28: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - accuracy: 0.9126 - dice_coef: 0.6484 - iou_metric: 0.5477 - loss: 0.5981 - val_accuracy: 0.8951 - val_dice_coef: 0.6582 - val_iou_metric: 0.5552 - val_loss: 0.6239 - learning_rate: 0.0010
# Epoch 29/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9182 - dice_coef: 0.6594 - iou_metric: 0.5676 - loss: 0.5688
# Epoch 29: val_dice_coef did not improve from 0.65823
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - accuracy: 0.9166 - dice_coef: 0.6626 - iou_metric: 0.5674 - loss: 0.5715 - val_accuracy: 0.9012 - val_dice_coef: 0.5676 - val_iou_metric: 0.4444 - val_loss: 0.7563 - learning_rate: 0.0010
# Epoch 30/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9185 - dice_coef: 0.6604 - iou_metric: 0.5692 - loss: 0.5733
# Epoch 30: val_dice_coef improved from 0.65823 to 0.68750, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 30: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.9190 - dice_coef: 0.6704 - iou_metric: 0.5771 - loss: 0.5624 - val_accuracy: 0.9183 - val_dice_coef: 0.6875 - val_iou_metric: 0.5809 - val_loss: 0.5684 - learning_rate: 0.0010
# Epoch 31/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9179 - dice_coef: 0.6753 - iou_metric: 0.5740 - loss: 0.5497
# Epoch 31: val_dice_coef improved from 0.68750 to 0.70349, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 31: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - accuracy: 0.9175 - dice_coef: 0.6730 - iou_metric: 0.5724 - loss: 0.5558 - val_accuracy: 0.9261 - val_dice_coef: 0.7035 - val_iou_metric: 0.6065 - val_loss: 0.5203 - learning_rate: 0.0010
# Epoch 32/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9241 - dice_coef: 0.6812 - iou_metric: 0.5876 - loss: 0.5353
# Epoch 32: val_dice_coef did not improve from 0.70349
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.9224 - dice_coef: 0.6841 - iou_metric: 0.5890 - loss: 0.5382 - val_accuracy: 0.9244 - val_dice_coef: 0.6821 - val_iou_metric: 0.5889 - val_loss: 0.5326 - learning_rate: 0.0010
# Epoch 33/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9267 - dice_coef: 0.6887 - iou_metric: 0.5990 - loss: 0.5207
# Epoch 33: val_dice_coef did not improve from 0.70349
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9208 - dice_coef: 0.6826 - iou_metric: 0.5891 - loss: 0.5439 - val_accuracy: 0.8852 - val_dice_coef: 0.6479 - val_iou_metric: 0.5198 - val_loss: 0.6770 - learning_rate: 0.0010
# Epoch 34/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9271 - dice_coef: 0.7088 - iou_metric: 0.6245 - loss: 0.5038
# Epoch 34: val_dice_coef did not improve from 0.70349
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.9260 - dice_coef: 0.6986 - iou_metric: 0.6081 - loss: 0.5177 - val_accuracy: 0.8887 - val_dice_coef: 0.6643 - val_iou_metric: 0.5447 - val_loss: 0.6299 - learning_rate: 0.0010
# Epoch 35/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9261 - dice_coef: 0.6994 - iou_metric: 0.6061 - loss: 0.5154
# Epoch 35: val_dice_coef did not improve from 0.70349
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9269 - dice_coef: 0.7007 - iou_metric: 0.6095 - loss: 0.5117 - val_accuracy: 0.9255 - val_dice_coef: 0.6822 - val_iou_metric: 0.5794 - val_loss: 0.5363 - learning_rate: 0.0010
# Epoch 36/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9239 - dice_coef: 0.6873 - iou_metric: 0.5931 - loss: 0.5438
# Epoch 36: val_dice_coef improved from 0.70349 to 0.71875, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 36: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.9268 - dice_coef: 0.7010 - iou_metric: 0.6101 - loss: 0.5132 - val_accuracy: 0.9338 - val_dice_coef: 0.7187 - val_iou_metric: 0.6394 - val_loss: 0.4839 - learning_rate: 0.0010
# Epoch 37/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9328 - dice_coef: 0.7240 - iou_metric: 0.6379 - loss: 0.4768
# Epoch 37: val_dice_coef did not improve from 0.71875
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9313 - dice_coef: 0.7222 - iou_metric: 0.6317 - loss: 0.4816 - val_accuracy: 0.9162 - val_dice_coef: 0.6534 - val_iou_metric: 0.5342 - val_loss: 0.6192 - learning_rate: 0.0010
# Epoch 38/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9351 - dice_coef: 0.7204 - iou_metric: 0.6306 - loss: 0.4784
# Epoch 38: val_dice_coef did not improve from 0.71875
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - accuracy: 0.9352 - dice_coef: 0.7361 - iou_metric: 0.6503 - loss: 0.4603 - val_accuracy: 0.9219 - val_dice_coef: 0.6762 - val_iou_metric: 0.6075 - val_loss: 0.5355 - learning_rate: 0.0010
# Epoch 39/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9341 - dice_coef: 0.7313 - iou_metric: 0.6454 - loss: 0.4613
# Epoch 39: val_dice_coef improved from 0.71875 to 0.73655, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 39: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.9336 - dice_coef: 0.7318 - iou_metric: 0.6430 - loss: 0.4672 - val_accuracy: 0.9324 - val_dice_coef: 0.7366 - val_iou_metric: 0.6291 - val_loss: 0.4988 - learning_rate: 0.0010
# Epoch 40/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9276 - dice_coef: 0.7296 - iou_metric: 0.6407 - loss: 0.4902
# Epoch 40: val_dice_coef did not improve from 0.73655
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9331 - dice_coef: 0.7285 - iou_metric: 0.6403 - loss: 0.4726 - val_accuracy: 0.9198 - val_dice_coef: 0.7033 - val_iou_metric: 0.6155 - val_loss: 0.5220 - learning_rate: 0.0010
# Epoch 41/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9379 - dice_coef: 0.7388 - iou_metric: 0.6509 - loss: 0.4514
# Epoch 41: val_dice_coef improved from 0.73655 to 0.74295, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 41: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - accuracy: 0.9367 - dice_coef: 0.7409 - iou_metric: 0.6550 - loss: 0.4487 - val_accuracy: 0.9335 - val_dice_coef: 0.7430 - val_iou_metric: 0.6485 - val_loss: 0.4620 - learning_rate: 0.0010
# Epoch 42/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9354 - dice_coef: 0.7419 - iou_metric: 0.6509 - loss: 0.4512
# Epoch 42: val_dice_coef did not improve from 0.74295
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - accuracy: 0.9371 - dice_coef: 0.7451 - iou_metric: 0.6566 - loss: 0.4438 - val_accuracy: 0.9270 - val_dice_coef: 0.7260 - val_iou_metric: 0.6386 - val_loss: 0.4859 - learning_rate: 0.0010
# Epoch 43/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9386 - dice_coef: 0.7549 - iou_metric: 0.6669 - loss: 0.4303
# Epoch 43: val_dice_coef did not improve from 0.74295
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9400 - dice_coef: 0.7579 - iou_metric: 0.6729 - loss: 0.4224 - val_accuracy: 0.9196 - val_dice_coef: 0.7345 - val_iou_metric: 0.6308 - val_loss: 0.4811 - learning_rate: 0.0010
# Epoch 44/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9389 - dice_coef: 0.7530 - iou_metric: 0.6679 - loss: 0.4359
# Epoch 44: val_dice_coef improved from 0.74295 to 0.76362, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 44: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.9408 - dice_coef: 0.7566 - iou_metric: 0.6718 - loss: 0.4208 - val_accuracy: 0.9352 - val_dice_coef: 0.7636 - val_iou_metric: 0.6563 - val_loss: 0.4553 - learning_rate: 0.0010
# Epoch 45/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9425 - dice_coef: 0.7690 - iou_metric: 0.6815 - loss: 0.4111
# Epoch 45: val_dice_coef improved from 0.76362 to 0.77476, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 45: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.9410 - dice_coef: 0.7693 - iou_metric: 0.6814 - loss: 0.4110 - val_accuracy: 0.9360 - val_dice_coef: 0.7748 - val_iou_metric: 0.6864 - val_loss: 0.4223 - learning_rate: 0.0010
# Epoch 46/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9355 - dice_coef: 0.7485 - iou_metric: 0.6607 - loss: 0.4437
# Epoch 46: val_dice_coef did not improve from 0.77476
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 64ms/step - accuracy: 0.9396 - dice_coef: 0.7593 - iou_metric: 0.6745 - loss: 0.4226 - val_accuracy: 0.9317 - val_dice_coef: 0.7237 - val_iou_metric: 0.6343 - val_loss: 0.4859 - learning_rate: 0.0010
# Epoch 47/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9370 - dice_coef: 0.7514 - iou_metric: 0.6686 - loss: 0.4438
# Epoch 47: val_dice_coef did not improve from 0.77476
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9442 - dice_coef: 0.7734 - iou_metric: 0.6945 - loss: 0.3982 - val_accuracy: 0.9294 - val_dice_coef: 0.7122 - val_iou_metric: 0.6163 - val_loss: 0.5215 - learning_rate: 0.0010
# Epoch 48/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9424 - dice_coef: 0.7612 - iou_metric: 0.6732 - loss: 0.4131
# Epoch 48: val_dice_coef did not improve from 0.77476
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9418 - dice_coef: 0.7704 - iou_metric: 0.6846 - loss: 0.4056 - val_accuracy: 0.9197 - val_dice_coef: 0.7283 - val_iou_metric: 0.6188 - val_loss: 0.5003 - learning_rate: 0.0010
# Epoch 49/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9438 - dice_coef: 0.7607 - iou_metric: 0.6774 - loss: 0.4080
# Epoch 49: val_dice_coef did not improve from 0.77476
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9429 - dice_coef: 0.7707 - iou_metric: 0.6866 - loss: 0.4020 - val_accuracy: 0.9402 - val_dice_coef: 0.7589 - val_iou_metric: 0.6678 - val_loss: 0.4263 - learning_rate: 0.0010
# Epoch 50/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9484 - dice_coef: 0.7799 - iou_metric: 0.7023 - loss: 0.3769
# Epoch 50: val_dice_coef did not improve from 0.77476
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - accuracy: 0.9467 - dice_coef: 0.7817 - iou_metric: 0.7036 - loss: 0.3797 - val_accuracy: 0.9382 - val_dice_coef: 0.7737 - val_iou_metric: 0.6948 - val_loss: 0.3993 - learning_rate: 0.0010
# Epoch 51/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9457 - dice_coef: 0.7769 - iou_metric: 0.6953 - loss: 0.3854
# Epoch 51: val_dice_coef did not improve from 0.77476
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.9438 - dice_coef: 0.7783 - iou_metric: 0.6960 - loss: 0.3903 - val_accuracy: 0.9417 - val_dice_coef: 0.7655 - val_iou_metric: 0.6794 - val_loss: 0.4120 - learning_rate: 0.0010
# Epoch 52/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9477 - dice_coef: 0.7902 - iou_metric: 0.7102 - loss: 0.3760
# Epoch 52: val_dice_coef did not improve from 0.77476
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.9462 - dice_coef: 0.7874 - iou_metric: 0.7059 - loss: 0.3794 - val_accuracy: 0.9420 - val_dice_coef: 0.7507 - val_iou_metric: 0.6793 - val_loss: 0.4210 - learning_rate: 0.0010
# Epoch 53/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9436 - dice_coef: 0.7698 - iou_metric: 0.6872 - loss: 0.4017
# Epoch 53: val_dice_coef did not improve from 0.77476
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9452 - dice_coef: 0.7766 - iou_metric: 0.6956 - loss: 0.3892 - val_accuracy: 0.9352 - val_dice_coef: 0.7519 - val_iou_metric: 0.6527 - val_loss: 0.4752 - learning_rate: 0.0010
# Epoch 54/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9495 - dice_coef: 0.7908 - iou_metric: 0.7107 - loss: 0.3659
# Epoch 54: val_dice_coef improved from 0.77476 to 0.77806, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 54: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.9489 - dice_coef: 0.7955 - iou_metric: 0.7165 - loss: 0.3589 - val_accuracy: 0.9413 - val_dice_coef: 0.7781 - val_iou_metric: 0.6914 - val_loss: 0.4069 - learning_rate: 0.0010
# Epoch 55/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9530 - dice_coef: 0.8052 - iou_metric: 0.7277 - loss: 0.3385
# Epoch 55: val_dice_coef did not improve from 0.77806
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - accuracy: 0.9495 - dice_coef: 0.7983 - iou_metric: 0.7181 - loss: 0.3577 - val_accuracy: 0.9192 - val_dice_coef: 0.7036 - val_iou_metric: 0.5953 - val_loss: 0.5444 - learning_rate: 0.0010
# Epoch 56/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9493 - dice_coef: 0.7987 - iou_metric: 0.7211 - loss: 0.3478
# Epoch 56: val_dice_coef did not improve from 0.77806
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.9498 - dice_coef: 0.7936 - iou_metric: 0.7120 - loss: 0.3588 - val_accuracy: 0.9319 - val_dice_coef: 0.7142 - val_iou_metric: 0.6033 - val_loss: 0.5252 - learning_rate: 0.0010
# Epoch 57/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9448 - dice_coef: 0.7953 - iou_metric: 0.7179 - loss: 0.3704
# Epoch 57: val_dice_coef improved from 0.77806 to 0.78179, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 57: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# ...
# Epoch 68: val_dice_coef did not improve from 0.82037
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.9586 - dice_coef: 0.8342 - iou_metric: 0.7616 - loss: 0.2958 - val_accuracy: 0.9521 - val_dice_coef: 0.8197 - val_iou_metric: 0.7425 - val_loss: 0.3414 - learning_rate: 5.0000e-04
# Epoch 69/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9608 - dice_coef: 0.8378 - iou_metric: 0.7716 - loss: 0.2815
# Epoch 69: val_dice_coef did not improve from 0.82037
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9598 - dice_coef: 0.8379 - iou_metric: 0.7690 - loss: 0.2857 - val_accuracy: 0.9494 - val_dice_coef: 0.8176 - val_iou_metric: 0.7390 - val_loss: 0.3416 - learning_rate: 5.0000e-04
# Epoch 70/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9592 - dice_coef: 0.8412 - iou_metric: 0.7718 - loss: 0.2945
# Epoch 70: val_dice_coef improved from 0.82037 to 0.82572, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 70: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - accuracy: 0.9621 - dice_coef: 0.8500 - iou_metric: 0.7848 - loss: 0.2701 - val_accuracy: 0.9525 - val_dice_coef: 0.8257 - val_iou_metric: 0.7461 - val_loss: 0.3352 - learning_rate: 2.5000e-04
# Epoch 71/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9633 - dice_coef: 0.8530 - iou_metric: 0.7889 - loss: 0.2635
# Epoch 71: val_dice_coef did not improve from 0.82572
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9639 - dice_coef: 0.8535 - iou_metric: 0.7890 - loss: 0.2609 - val_accuracy: 0.9517 - val_dice_coef: 0.8242 - val_iou_metric: 0.7441 - val_loss: 0.3334 - learning_rate: 2.5000e-04
# Epoch 72/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9656 - dice_coef: 0.8586 - iou_metric: 0.7956 - loss: 0.2487
# Epoch 72: val_dice_coef improved from 0.82572 to 0.83231, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 72: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - accuracy: 0.9648 - dice_coef: 0.8580 - iou_metric: 0.7940 - loss: 0.2529 - val_accuracy: 0.9538 - val_dice_coef: 0.8323 - val_iou_metric: 0.7467 - val_loss: 0.3260 - learning_rate: 2.5000e-04
# Epoch 73/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9668 - dice_coef: 0.8637 - iou_metric: 0.7987 - loss: 0.2403
# Epoch 73: val_dice_coef improved from 0.83231 to 0.83523, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 73: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.9640 - dice_coef: 0.8568 - iou_metric: 0.7917 - loss: 0.2562 - val_accuracy: 0.9550 - val_dice_coef: 0.8352 - val_iou_metric: 0.7521 - val_loss: 0.3174 - learning_rate: 2.5000e-04
# Epoch 74/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9644 - dice_coef: 0.8510 - iou_metric: 0.7853 - loss: 0.2619
# Epoch 74: val_dice_coef improved from 0.83523 to 0.83719, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 74: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - accuracy: 0.9651 - dice_coef: 0.8572 - iou_metric: 0.7937 - loss: 0.2530 - val_accuracy: 0.9535 - val_dice_coef: 0.8372 - val_iou_metric: 0.7553 - val_loss: 0.3136 - learning_rate: 2.5000e-04
# Epoch 75/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9658 - dice_coef: 0.8577 - iou_metric: 0.7942 - loss: 0.2507
# Epoch 75: val_dice_coef did not improve from 0.83719
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - accuracy: 0.9648 - dice_coef: 0.8518 - iou_metric: 0.7855 - loss: 0.2585 - val_accuracy: 0.9476 - val_dice_coef: 0.8092 - val_iou_metric: 0.7234 - val_loss: 0.3637 - learning_rate: 2.5000e-04
# Epoch 76/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9675 - dice_coef: 0.8616 - iou_metric: 0.7961 - loss: 0.2448
# Epoch 76: val_dice_coef did not improve from 0.83719
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - accuracy: 0.9663 - dice_coef: 0.8625 - iou_metric: 0.7983 - loss: 0.2470 - val_accuracy: 0.9489 - val_dice_coef: 0.8089 - val_iou_metric: 0.7163 - val_loss: 0.3687 - learning_rate: 2.5000e-04
# Epoch 77/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9648 - dice_coef: 0.8606 - iou_metric: 0.7960 - loss: 0.2504
# Epoch 77: val_dice_coef did not improve from 0.83719
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - accuracy: 0.9663 - dice_coef: 0.8649 - iou_metric: 0.8026 - loss: 0.2404 - val_accuracy: 0.9558 - val_dice_coef: 0.8296 - val_iou_metric: 0.7593 - val_loss: 0.3147 - learning_rate: 2.5000e-04
# Epoch 78/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9645 - dice_coef: 0.8642 - iou_metric: 0.7993 - loss: 0.2450
# Epoch 78: val_dice_coef did not improve from 0.83719
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9657 - dice_coef: 0.8663 - iou_metric: 0.8041 - loss: 0.2414 - val_accuracy: 0.9539 - val_dice_coef: 0.8227 - val_iou_metric: 0.7385 - val_loss: 0.3341 - learning_rate: 2.5000e-04
# Epoch 79/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9671 - dice_coef: 0.8670 - iou_metric: 0.8068 - loss: 0.2388
# Epoch 79: val_dice_coef did not improve from 0.83719
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9658 - dice_coef: 0.8627 - iou_metric: 0.7998 - loss: 0.2482 - val_accuracy: 0.9520 - val_dice_coef: 0.8264 - val_iou_metric: 0.7395 - val_loss: 0.3435 - learning_rate: 2.5000e-04
# Epoch 80/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9643 - dice_coef: 0.8614 - iou_metric: 0.7949 - loss: 0.2450
# Epoch 80: val_dice_coef improved from 0.83719 to 0.83813, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 80: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.9666 - dice_coef: 0.8680 - iou_metric: 0.8050 - loss: 0.2336 - val_accuracy: 0.9541 - val_dice_coef: 0.8381 - val_iou_metric: 0.7598 - val_loss: 0.3152 - learning_rate: 2.5000e-04
# Epoch 81/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9688 - dice_coef: 0.8731 - iou_metric: 0.8121 - loss: 0.2221
# Epoch 81: val_dice_coef did not improve from 0.83813
#
# Epoch 81: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - accuracy: 0.9667 - dice_coef: 0.8651 - iou_metric: 0.8017 - loss: 0.2388 - val_accuracy: 0.9550 - val_dice_coef: 0.8348 - val_iou_metric: 0.7545 - val_loss: 0.3192 - learning_rate: 2.5000e-04
# Epoch 82/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9675 - dice_coef: 0.8539 - iou_metric: 0.7900 - loss: 0.2501
# Epoch 82: val_dice_coef did not improve from 0.83813
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - accuracy: 0.9658 - dice_coef: 0.8591 - iou_metric: 0.7956 - loss: 0.2473 - val_accuracy: 0.9549 - val_dice_coef: 0.8344 - val_iou_metric: 0.7537 - val_loss: 0.3130 - learning_rate: 1.2500e-04
# Epoch 83/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9724 - dice_coef: 0.8822 - iou_metric: 0.8269 - loss: 0.2064
# Epoch 83: val_dice_coef improved from 0.83813 to 0.84568, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 83: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - accuracy: 0.9687 - dice_coef: 0.8754 - iou_metric: 0.8160 - loss: 0.2236 - val_accuracy: 0.9572 - val_dice_coef: 0.8457 - val_iou_metric: 0.7720 - val_loss: 0.3007 - learning_rate: 1.2500e-04
# Epoch 84/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9696 - dice_coef: 0.8699 - iou_metric: 0.8093 - loss: 0.2279
# Epoch 84: val_dice_coef did not improve from 0.84568
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - accuracy: 0.9683 - dice_coef: 0.8709 - iou_metric: 0.8116 - loss: 0.2279 - val_accuracy: 0.9559 - val_dice_coef: 0.8385 - val_iou_metric: 0.7584 - val_loss: 0.3099 - learning_rate: 1.2500e-04
# Epoch 85/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9681 - dice_coef: 0.8746 - iou_metric: 0.8127 - loss: 0.2254
# Epoch 85: val_dice_coef did not improve from 0.84568
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9689 - dice_coef: 0.8765 - iou_metric: 0.8158 - loss: 0.2224 - val_accuracy: 0.9552 - val_dice_coef: 0.8371 - val_iou_metric: 0.7539 - val_loss: 0.3196 - learning_rate: 1.2500e-04
# Epoch 86/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9694 - dice_coef: 0.8807 - iou_metric: 0.8221 - loss: 0.2166
# Epoch 86: val_dice_coef improved from 0.84568 to 0.84793, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 86: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - accuracy: 0.9681 - dice_coef: 0.8732 - iou_metric: 0.8101 - loss: 0.2285 - val_accuracy: 0.9565 - val_dice_coef: 0.8479 - val_iou_metric: 0.7680 - val_loss: 0.3017 - learning_rate: 1.2500e-04
# Epoch 87/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9709 - dice_coef: 0.8809 - iou_metric: 0.8210 - loss: 0.2127
# Epoch 87: val_dice_coef did not improve from 0.84793
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - accuracy: 0.9682 - dice_coef: 0.8745 - iou_metric: 0.8135 - loss: 0.2272 - val_accuracy: 0.9568 - val_dice_coef: 0.8425 - val_iou_metric: 0.7628 - val_loss: 0.3046 - learning_rate: 1.2500e-04
# Epoch 88/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9662 - dice_coef: 0.8702 - iou_metric: 0.8085 - loss: 0.2328
# Epoch 88: val_dice_coef did not improve from 0.84793
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9687 - dice_coef: 0.8761 - iou_metric: 0.8184 - loss: 0.2182 - val_accuracy: 0.9552 - val_dice_coef: 0.8404 - val_iou_metric: 0.7615 - val_loss: 0.3043 - learning_rate: 1.2500e-04
# Epoch 89/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9694 - dice_coef: 0.8779 - iou_metric: 0.8200 - loss: 0.2209
# Epoch 89: val_dice_coef did not improve from 0.84793
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - accuracy: 0.9691 - dice_coef: 0.8733 - iou_metric: 0.8136 - loss: 0.2256 - val_accuracy: 0.9553 - val_dice_coef: 0.8337 - val_iou_metric: 0.7546 - val_loss: 0.3202 - learning_rate: 1.2500e-04
# Epoch 90/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9727 - dice_coef: 0.8858 - iou_metric: 0.8328 - loss: 0.2001
# Epoch 90: val_dice_coef did not improve from 0.84793
#
# Epoch 90: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9697 - dice_coef: 0.8809 - iou_metric: 0.8237 - loss: 0.2149 - val_accuracy: 0.9557 - val_dice_coef: 0.8397 - val_iou_metric: 0.7589 - val_loss: 0.3139 - learning_rate: 1.2500e-04
# Epoch 91/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9672 - dice_coef: 0.8732 - iou_metric: 0.8114 - loss: 0.2252
# Epoch 91: val_dice_coef did not improve from 0.84793
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9695 - dice_coef: 0.8757 - iou_metric: 0.8167 - loss: 0.2188 - val_accuracy: 0.9565 - val_dice_coef: 0.8415 - val_iou_metric: 0.7602 - val_loss: 0.3053 - learning_rate: 6.2500e-05
# Epoch 92/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9681 - dice_coef: 0.8768 - iou_metric: 0.8181 - loss: 0.2259
# Epoch 92: val_dice_coef did not improve from 0.84793
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.9701 - dice_coef: 0.8781 - iou_metric: 0.8204 - loss: 0.2180 - val_accuracy: 0.9563 - val_dice_coef: 0.8468 - val_iou_metric: 0.7678 - val_loss: 0.3029 - learning_rate: 6.2500e-05
# Epoch 93/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9674 - dice_coef: 0.8658 - iou_metric: 0.8022 - loss: 0.2414
# Epoch 93: val_dice_coef did not improve from 0.84793
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9696 - dice_coef: 0.8756 - iou_metric: 0.8165 - loss: 0.2207 - val_accuracy: 0.9561 - val_dice_coef: 0.8374 - val_iou_metric: 0.7535 - val_loss: 0.3094 - learning_rate: 6.2500e-05
# Epoch 94/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9727 - dice_coef: 0.8865 - iou_metric: 0.8320 - loss: 0.1988
# Epoch 94: val_dice_coef did not improve from 0.84793
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - accuracy: 0.9698 - dice_coef: 0.8798 - iou_metric: 0.8183 - loss: 0.2159 - val_accuracy: 0.9565 - val_dice_coef: 0.8429 - val_iou_metric: 0.7643 - val_loss: 0.3063 - learning_rate: 6.2500e-05
# Epoch 95/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9699 - dice_coef: 0.8809 - iou_metric: 0.8245 - loss: 0.2143
# Epoch 95: val_dice_coef did not improve from 0.84793
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.9714 - dice_coef: 0.8829 - iou_metric: 0.8279 - loss: 0.2077 - val_accuracy: 0.9567 - val_dice_coef: 0.8462 - val_iou_metric: 0.7689 - val_loss: 0.3035 - learning_rate: 6.2500e-05
# Epoch 96/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9738 - dice_coef: 0.8903 - iou_metric: 0.8357 - loss: 0.1954
# Epoch 96: val_dice_coef did not improve from 0.84793
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9709 - dice_coef: 0.8846 - iou_metric: 0.8272 - loss: 0.2091 - val_accuracy: 0.9568 - val_dice_coef: 0.8419 - val_iou_metric: 0.7585 - val_loss: 0.3103 - learning_rate: 6.2500e-05
# Epoch 97/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9675 - dice_coef: 0.8741 - iou_metric: 0.8138 - loss: 0.2252
# Epoch 97: val_dice_coef did not improve from 0.84793
#
# Epoch 97: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - accuracy: 0.9702 - dice_coef: 0.8785 - iou_metric: 0.8213 - loss: 0.2138 - val_accuracy: 0.9570 - val_dice_coef: 0.8442 - val_iou_metric: 0.7658 - val_loss: 0.3049 - learning_rate: 6.2500e-05
# Epoch 98/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9684 - dice_coef: 0.8730 - iou_metric: 0.8101 - loss: 0.2261
# Epoch 98: val_dice_coef did not improve from 0.84793
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - accuracy: 0.9702 - dice_coef: 0.8798 - iou_metric: 0.8211 - loss: 0.2135 - val_accuracy: 0.9573 - val_dice_coef: 0.8422 - val_iou_metric: 0.7616 - val_loss: 0.3060 - learning_rate: 3.1250e-05
# Epoch 99/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9718 - dice_coef: 0.8845 - iou_metric: 0.8259 - loss: 0.2050
# Epoch 99: val_dice_coef did not improve from 0.84793
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9702 - dice_coef: 0.8828 - iou_metric: 0.8242 - loss: 0.2117 - val_accuracy: 0.9569 - val_dice_coef: 0.8455 - val_iou_metric: 0.7668 - val_loss: 0.3022 - learning_rate: 3.1250e-05
# Epoch 100/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9735 - dice_coef: 0.8945 - iou_metric: 0.8440 - loss: 0.1856
# Epoch 100: val_dice_coef improved from 0.84793 to 0.84876, saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
#
# Epoch 100: finished saving model to /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/models/best_unet_v3.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.9723 - dice_coef: 0.8885 - iou_metric: 0.8357 - loss: 0.1970 - val_accuracy: 0.9575 - val_dice_coef: 0.8488 - val_iou_metric: 0.7681 - val_loss: 0.2982 - learning_rate: 3.1250e-05
# Restoring model weights from the end of the best epoch: 100.
# ========== Training Complete ==========

# %%
 if images:
        test_and_display(unet, images[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 if images:
#       2        test_and_display(unet, images[1])
#
# NameError: name 'images' is not defined
