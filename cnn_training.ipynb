# %%
import tensorflow as tf

print(tf.__version__)
print(tf.config.list_physical_devices('GPU'))
print(tf.test.is_built_with_cuda())
#checking complete
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778219163.259901    6763 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.21.0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# True

# %%
import tensorflow as tf
from tensorflow.keras import models,layers
import matplotlib.pyplot as plt
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778219385.595337    7784 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 8
EPOCHS = 50
CHANNELS = 3

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/DataSets/PlantVillage",
    shuffle=True,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
print(dataset)
# Out:
# Found 2152 files belonging to 3 classes.
# W0000 00:00:1778219428.721197    7784 gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was false.
# I0000 00:00:1778219428.721470    7784 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5563 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
import os
dataset_path = "/mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/DataSets/PlantVillage"
print(os.path.exists(dataset_path))

# %%
class_names = dataset.class_names
class_names
len(dataset)
# Out:
# 269

# %%
for image_batch, label_batch in dataset.take(1):
    print(image_batch.shape)
    # print(label_batch.numpy())
# Out:
# (8, 256, 256, 3)

# %%
# Printing the first image of 32 images
for image_batch, label_batch in dataset.take(1):
    print(image_batch[31])
# Out:
# W0000 00:00:1778219230.027717    6763 op_kernel.cc:1858] OP_REQUIRES failed at strided_slice_op.cc:117 : INVALID_ARGUMENT: slice index 31 of dimension 0 out of bounds.
# W0000 00:00:1778219230.027772    6763 local_rendezvous.cc:412] Local rendezvous is aborting with status: INVALID_ARGUMENT: slice index 31 of dimension 0 out of bounds.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Printing the first image of 32 images
#       2 for image_batch, label_batch in dataset.take(1):
# ----> 3     print(image_batch[31])
#
# File /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/linux-venv/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:167, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     165 except Exception as e:
#     166   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 167   raise e.with_traceback(filtered_tb) from None
#     168 finally:
#     169   del filtered_tb
#
# File /mnt/c/development/Thesis/PotatoDiseaseClassification-CNN/linux-venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py:6027, in raise_from_not_ok_status(e, name)
#    6025 def raise_from_not_ok_status(e, name) -> NoReturn:
#    6026   e.message += (" name: " + str(name if name is not None else ""))
# -> 6027   raise core._status_to_exception(e) from None
#
# InvalidArgumentError: {{function_node __wrapped__StridedSlice_device_/job:localhost/replica:0/task:0/device:GPU:0}} slice index 31 of dimension 0 out of bounds. [Op:StridedSlice] name: strided_slice/

# %%
plt.figure(figsize=(10,10))
for image_batch, label_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[label_batch[i]])
        plt.axis("off")

# %%
len(dataset)

# %%
# 80% ==> Training data
# 20% ==> 10% validation, 10% testing

# %%
def get_dataset_partitions_tf(ds, train_split=0.8,val_split=0.1, test_split=0.1, shuffle=True, shuffle_size = 10000):
    ds_size = len(ds)
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed = 12)
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# preprocessing pipeline
resize_and_rescale = tf.keras.Sequential([
  layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
  layers.Rescaling(1.0/255)
])

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2)
])

# %%
print("OK")

# %%
# Define input_shape for a single image
input_shape_single = (IMAGE_SIZE, IMAGE_SIZE, CHANNELS)

n_classes = 3

model = models.Sequential([
    
    # Input Layer
    layers.Input(shape=input_shape_single),

    resize_and_rescale,
    data_augmentation,

    # CNN Layer 1
    layers.Conv2D(32, (3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),

    # CNN Layer 2
    layers.Conv2D(64, (3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),

    # CNN Layer 3
    layers.Conv2D(64, (3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),

    # Fully Connected Layers
    layers.Flatten(),
    layers.Dense(64, activation='relu'),

    # Output Layer
    layers.Dense(n_classes, activation='softmax')
])

# Build model


# Model summary
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_3 (Sequential)       │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_4 (Sequential)       │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 254, 254, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 127, 127, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 125, 125, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 60, 60, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 57600)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │     3,686,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,742,979 (14.28 MB)
#  Trainable params: 3,742,979 (14.28 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False), metrics=['accuracy'])

# %%
history = model.fit(train_ds, epochs=EPOCHS,batch_size = BATCH_SIZE, verbose=1,validation_data=val_ds)
# Out:
# Epoch 1/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 10s 110ms/step - accuracy: 0.6933 - loss: 0.8121 - val_accuracy: 0.7865 - val_loss: 0.6217
# Epoch 2/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.8426 - loss: 0.4078 - val_accuracy: 0.8750 - val_loss: 0.3407
# Epoch 3/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.8565 - loss: 0.3595 - val_accuracy: 0.8698 - val_loss: 0.3483
# Epoch 4/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9149 - loss: 0.2163 - val_accuracy: 0.9271 - val_loss: 0.1278
# Epoch 5/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9416 - loss: 0.1459 - val_accuracy: 0.8333 - val_loss: 0.3834
# Epoch 6/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9439 - loss: 0.1594 - val_accuracy: 0.9531 - val_loss: 0.1089
# Epoch 7/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9473 - loss: 0.1326 - val_accuracy: 0.8906 - val_loss: 0.2155
# Epoch 8/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9653 - loss: 0.0906 - val_accuracy: 0.9323 - val_loss: 0.1476
# Epoch 9/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9606 - loss: 0.1026 - val_accuracy: 0.9740 - val_loss: 0.0712
# Epoch 10/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9647 - loss: 0.0950 - val_accuracy: 0.9531 - val_loss: 0.1430
# Epoch 11/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9664 - loss: 0.0901 - val_accuracy: 0.9583 - val_loss: 0.0954
# Epoch 12/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9699 - loss: 0.0789 - val_accuracy: 0.9740 - val_loss: 0.0656
# Epoch 13/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9693 - loss: 0.0931 - val_accuracy: 0.9323 - val_loss: 0.1751
# Epoch 14/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9624 - loss: 0.0993 - val_accuracy: 0.9115 - val_loss: 0.2000
# Epoch 15/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9670 - loss: 0.0879 - val_accuracy: 0.9219 - val_loss: 0.2134
# Epoch 16/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9682 - loss: 0.0767 - val_accuracy: 0.9635 - val_loss: 0.0843
# Epoch 17/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9728 - loss: 0.0905 - val_accuracy: 0.9531 - val_loss: 0.0916
# Epoch 18/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9716 - loss: 0.0759 - val_accuracy: 0.9583 - val_loss: 0.0848
# Epoch 19/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9757 - loss: 0.0689 - val_accuracy: 0.9583 - val_loss: 0.1011
# Epoch 20/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9792 - loss: 0.0565 - val_accuracy: 0.8646 - val_loss: 0.4619
# Epoch 21/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9653 - loss: 0.0930 - val_accuracy: 0.9583 - val_loss: 0.0948
# Epoch 22/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9693 - loss: 0.0777 - val_accuracy: 0.9115 - val_loss: 0.2064
# Epoch 23/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9832 - loss: 0.0494 - val_accuracy: 0.9479 - val_loss: 0.1355
# Epoch 24/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9722 - loss: 0.0734 - val_accuracy: 0.9375 - val_loss: 0.1892
# Epoch 25/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9832 - loss: 0.0452 - val_accuracy: 0.9792 - val_loss: 0.0461
# Epoch 26/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9745 - loss: 0.0680 - val_accuracy: 0.8646 - val_loss: 0.4503
# Epoch 27/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9716 - loss: 0.0726 - val_accuracy: 0.9635 - val_loss: 0.1084
# Epoch 28/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9838 - loss: 0.0460 - val_accuracy: 0.9688 - val_loss: 0.0721
# Epoch 29/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9850 - loss: 0.0422 - val_accuracy: 0.9271 - val_loss: 0.2068
# Epoch 30/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9884 - loss: 0.0279 - val_accuracy: 0.9635 - val_loss: 0.0820
# Epoch 31/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9751 - loss: 0.0640 - val_accuracy: 0.9635 - val_loss: 0.0825
# Epoch 32/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9832 - loss: 0.0483 - val_accuracy: 0.9688 - val_loss: 0.0627
# Epoch 33/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9826 - loss: 0.0503 - val_accuracy: 0.9427 - val_loss: 0.1822
# Epoch 34/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9890 - loss: 0.0288 - val_accuracy: 0.9688 - val_loss: 0.0595
# Epoch 35/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9884 - loss: 0.0302 - val_accuracy: 0.8594 - val_loss: 0.5434
# Epoch 36/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9867 - loss: 0.0415 - val_accuracy: 0.9531 - val_loss: 0.1107
# Epoch 37/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9913 - loss: 0.0316 - val_accuracy: 0.9167 - val_loss: 0.1938
# Epoch 38/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9855 - loss: 0.0391 - val_accuracy: 0.9896 - val_loss: 0.0312
# Epoch 39/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9884 - loss: 0.0343 - val_accuracy: 0.9115 - val_loss: 0.3387
# Epoch 40/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9850 - loss: 0.0399 - val_accuracy: 0.9010 - val_loss: 0.2794
# Epoch 41/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9797 - loss: 0.0494 - val_accuracy: 0.9531 - val_loss: 0.1393
# Epoch 42/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9821 - loss: 0.0472 - val_accuracy: 0.9479 - val_loss: 0.1356
# Epoch 43/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9774 - loss: 0.0616 - val_accuracy: 0.9740 - val_loss: 0.0442
# Epoch 44/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9873 - loss: 0.0316 - val_accuracy: 0.9792 - val_loss: 0.0478
# Epoch 45/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9861 - loss: 0.0376 - val_accuracy: 0.9323 - val_loss: 0.2111
# Epoch 46/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9855 - loss: 0.0364 - val_accuracy: 0.9531 - val_loss: 0.1354
# Epoch 47/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9936 - loss: 0.0208 - val_accuracy: 0.9583 - val_loss: 0.1061
# Epoch 48/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9942 - loss: 0.0187 - val_accuracy: 0.9531 - val_loss: 0.1397
# Epoch 49/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9977 - loss: 0.0150 - val_accuracy: 0.9531 - val_loss: 0.1487
# Epoch 50/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9942 - loss: 0.0164 - val_accuracy: 0.9740 - val_loss: 0.0519

# %%
scores = model.evaluate(test_ds)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.9766 - loss: 0.0867

# %%
scores
# Out:
# [0.05182516574859619, 0.97265625]

# %%
history

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 50, 'steps': 54}

# %%
acc= history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and validation Accuracy')

# %%
plt.subplot(1,2,2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import numpy as np
for image_batch, labels_batch in test_ds.take(1):
    plt.imshow(image_batch[0].numpy().astype('uint8'))
    first_image =image_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    print("first image to predict")
    plt.imshow(first_image)
    print("first images's actual label:", class_names[first_label])
    batch_prediction = model.predict(image_batch)
    print(batch_prediction[0])
    print(np.argmax(batch_prediction[0]))
    print("Predicted Label:", class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# first images's actual label: Potato___Late_blight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 728ms/step
# [1.7502403e-08 1.0000000e+00 1.1727142e-15]
# 1
# Predicted Label: Potato___Late_blight

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array,0) # this will create a batch
    predictions = model.predict(img_array)
    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100* (np.max(predictions[0])),2)
    return predicted_class,confidence

# %%
plt.figure(figsize=(12,12))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3,3,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]]
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}")
        plt.axis("off")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
model_version = 1
model.save(f"./models/snet/model_v{model_version}.keras")
